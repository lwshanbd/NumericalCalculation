# %% [markdown]
# # 第五章
# ## 题目1
#
# > 注：本题为验证公式的正确性，选用《数值方法》课本例题作为验证，验证程序的正确性。该题目的要求为，$y=2+sin(2\sqrt{x})$,设立10个区间（即11个点），计算从1到6的积分值。
#
# ### 组合梯形公式
#
# 设函数划分宽度为$h$，一共有$M+1$个点，即$M$个区间。考虑到计算的简便性，采用以下公式计算函数的积分值
# $$T(f,h)=\frac{h}{2}(f(a)+f(b))+h\sum_{k=1}^{M-1} f(x_k)$$

# %%
# f为原函数
import math


def f(x):
    return 2+math.sin(2*(x**0.5))


def trapezoid(f, a, b, M):
    sum = 0
    h = (b-a)/M
    # print(h)
    for i in range(1, M):
        sum += f(i*h+a)
        # print(f(i*h+a))

    return (h/2)*(f(a)+f(b))+sum*h


trapezoid(f, 1, 6, 10)
# Out:
# 8.193854565172531

# %% [markdown]
# ### 辛普森公式
#
# 设一共有2M个区间，每个区间等距，距离为$h$,选用组合辛普森公式公式一进行计算，即
# $$S(f,h)=\frac{h}{3}\sum_{k=1}^{M}(f(x_{2k-2})+4f(x_{2k-1})+f(x_{2k}))$$

# %%
def simpson(f, a, b, M):
    h = (b - a) / (2 * M)
    s = 0
    for k in range(1, M + 1):
        s += f(a + (2 * k - 2) * h) + 4 * f(a + (2 * k - 1) * h) + f(a + 2 * k * h)
    s *= h / 3
    return s

simpson(f,2,6,15)
# Out:
# 8.183472811131802

# %%
0.3413447460685431-simpson(g,0,1,2)/(math.sqrt(2*math.pi))
# Out:
# -1.074178810606119e-05

# %% [markdown]
# ## 题目2
#
# 取$h=0.01$,分别利用复合梯形公式和辛普森公式，计算定积分
# $$I(x)=\frac{1}{\sqrt{2 \pi}} \int_{0}^{1} \exp ^{-\frac{x^{2}}{2}} \mathrm{d} x$$

# %%
from sympy import *
def g(x):
    return math.exp(-x*x/2)

def I_simpson(h):
    M=int(2/h)
    c=1/(math.sqrt(2*math.pi))
    #print(c*simpson(g,0,1,M))
    return c*simpson(g,0,1,M)
    
def I_trapezoid(h):
    M=int(1/h)
    c=1/(math.sqrt(2*math.pi))
    #print(c*trapezoid(g,0,1,M))
    return c*trapezoid(g,0,1,M)

# %%
from scipy import integrate
x2 = lambda x: math.exp(-x*x/2)
ans=integrate.quad(x2, 0, 1)[0]*1/(math.sqrt(2*math.pi))
ans
# Out:
# 0.3413447460685431

# %%
for i in range(1,140):
    print("$$h_{%d}=%.2f,I(x)=%.12f$$"%(i-1,i*0.01,I_simpson(i*0.01)-ans))
# Out:
# $$h_{0}=0.01,I(x)=0.000000000000$$
# $$h_{1}=0.02,I(x)=0.000000000002$$
# $$h_{2}=0.03,I(x)=0.000000000009$$
# $$h_{3}=0.04,I(x)=0.000000000027$$
# $$h_{4}=0.05,I(x)=0.000000000066$$
# $$h_{5}=0.06,I(x)=0.000000000142$$
# $$h_{6}=0.07,I(x)=0.000000000273$$
# $$h_{7}=0.08,I(x)=0.000000000430$$
# $$h_{8}=0.09,I(x)=0.000000000717$$
# $$h_{9}=0.10,I(x)=0.000000001050$$
# $$h_{10}=0.11,I(x)=0.000000001601$$
# $$h_{11}=0.12,I(x)=0.000000002565$$
# $$h_{12}=0.13,I(x)=0.000000003321$$
# $$h_{13}=0.14,I(x)=0.000000004376$$
# $$h_{14}=0.15,I(x)=0.000000005886$$
# $$h_{15}=0.16,I(x)=0.000000008109$$
# $$h_{16}=0.17,I(x)=0.000000011486$$
# $$h_{17}=0.18,I(x)=0.000000011486$$
# $$h_{18}=0.19,I(x)=0.000000016819$$
# $$h_{19}=0.20,I(x)=0.000000016819$$
# $$h_{20}=0.21,I(x)=0.000000025639$$
# $$h_{21}=0.22,I(x)=0.000000025639$$
# $$h_{22}=0.23,I(x)=0.000000041082$$
# $$h_{23}=0.24,I(x)=0.000000041082$$
# $$h_{24}=0.25,I(x)=0.000000041082$$
# $$h_{25}=0.26,I(x)=0.000000070113$$
# $$h_{26}=0.27,I(x)=0.000000070113$$
# $$h_{27}=0.28,I(x)=0.000000070113$$
# $$h_{28}=0.29,I(x)=0.000000129979$$
# $$h_{29}=0.30,I(x)=0.000000129979$$
# $$h_{30}=0.31,I(x)=0.000000129979$$
# $$h_{31}=0.32,I(x)=0.000000129979$$
# $$h_{32}=0.33,I(x)=0.000000129979$$
# $$h_{33}=0.34,I(x)=0.000000269820$$
# $$h_{34}=0.35,I(x)=0.000000269820$$
# $$h_{35}=0.36,I(x)=0.000000269820$$
# $$h_{36}=0.37,I(x)=0.000000269820$$
# $$h_{37}=0.38,I(x)=0.000000269820$$
# $$h_{38}=0.39,I(x)=0.000000269820$$
# $$h_{39}=0.40,I(x)=0.000000269820$$
# $$h_{40}=0.41,I(x)=0.000000660071$$
# $$h_{41}=0.42,I(x)=0.000000660071$$
# $$h_{42}=0.43,I(x)=0.000000660071$$
# $$h_{43}=0.44,I(x)=0.000000660071$$
# $$h_{44}=0.45,I(x)=0.000000660071$$
# $$h_{45}=0.46,I(x)=0.000000660071$$
# $$h_{46}=0.47,I(x)=0.000000660071$$
# $$h_{47}=0.48,I(x)=0.000000660071$$
# $$h_{48}=0.49,I(x)=0.000000660071$$
# $$h_{49}=0.50,I(x)=0.000000660071$$
# $$h_{50}=0.51,I(x)=0.000002095290$$
# $$h_{51}=0.52,I(x)=0.000002095290$$
# $$h_{52}=0.53,I(x)=0.000002095290$$
# $$h_{53}=0.54,I(x)=0.000002095290$$
# $$h_{54}=0.55,I(x)=0.000002095290$$
# $$h_{55}=0.56,I(x)=0.000002095290$$
# $$h_{56}=0.57,I(x)=0.000002095290$$
# $$h_{57}=0.58,I(x)=0.000002095290$$
# $$h_{58}=0.59,I(x)=0.000002095290$$
# $$h_{59}=0.60,I(x)=0.000002095290$$
# $$h_{60}=0.61,I(x)=0.000002095290$$
# $$h_{61}=0.62,I(x)=0.000002095290$$
# $$h_{62}=0.63,I(x)=0.000002095290$$
# $$h_{63}=0.64,I(x)=0.000002095290$$
# $$h_{64}=0.65,I(x)=0.000002095290$$
# $$h_{65}=0.66,I(x)=0.000002095290$$
# $$h_{66}=0.67,I(x)=0.000010741788$$
# $$h_{67}=0.68,I(x)=0.000010741788$$
# $$h_{68}=0.69,I(x)=0.000010741788$$
# $$h_{69}=0.70,I(x)=0.000010741788$$
# $$h_{70}=0.71,I(x)=0.000010741788$$
# $$h_{71}=0.72,I(x)=0.000010741788$$
# $$h_{72}=0.73,I(x)=0.000010741788$$
# $$h_{73}=0.74,I(x)=0.000010741788$$
# $$h_{74}=0.75,I(x)=0.000010741788$$
# $$h_{75}=0.76,I(x)=0.000010741788$$
# $$h_{76}=0.77,I(x)=0.000010741788$$
# $$h_{77}=0.78,I(x)=0.000010741788$$
# $$h_{78}=0.79,I(x)=0.000010741788$$
# $$h_{79}=0.80,I(x)=0.000010741788$$
# $$h_{80}=0.81,I(x)=0.000010741788$$
# $$h_{81}=0.82,I(x)=0.000010741788$$
# $$h_{82}=0.83,I(x)=0.000010741788$$
# $$h_{83}=0.84,I(x)=0.000010741788$$
# $$h_{84}=0.85,I(x)=0.000010741788$$
# $$h_{85}=0.86,I(x)=0.000010741788$$
# $$h_{86}=0.87,I(x)=0.000010741788$$
# $$h_{87}=0.88,I(x)=0.000010741788$$
# $$h_{88}=0.89,I(x)=0.000010741788$$
# $$h_{89}=0.90,I(x)=0.000010741788$$
# $$h_{90}=0.91,I(x)=0.000010741788$$
# $$h_{91}=0.92,I(x)=0.000010741788$$
# $$h_{92}=0.93,I(x)=0.000010741788$$
# $$h_{93}=0.94,I(x)=0.000010741788$$
# $$h_{94}=0.95,I(x)=0.000010741788$$
# $$h_{95}=0.96,I(x)=0.000010741788$$
# $$h_{96}=0.97,I(x)=0.000010741788$$
# $$h_{97}=0.98,I(x)=0.000010741788$$
# $$h_{98}=0.99,I(x)=0.000010741788$$
# $$h_{99}=1.00,I(x)=0.000010741788$$
# $$h_{100}=1.01,I(x)=0.000184305928$$
# $$h_{101}=1.02,I(x)=0.000184305928$$
# $$h_{102}=1.03,I(x)=0.000184305928$$
# $$h_{103}=1.04,I(x)=0.000184305928$$
# $$h_{104}=1.05,I(x)=0.000184305928$$
# $$h_{105}=1.06,I(x)=0.000184305928$$
# $$h_{106}=1.07,I(x)=0.000184305928$$
# $$h_{107}=1.08,I(x)=0.000184305928$$
# $$h_{108}=1.09,I(x)=0.000184305928$$
# $$h_{109}=1.10,I(x)=0.000184305928$$
# $$h_{110}=1.11,I(x)=0.000184305928$$
# $$h_{111}=1.12,I(x)=0.000184305928$$
# $$h_{112}=1.13,I(x)=0.000184305928$$
# $$h_{113}=1.14,I(x)=0.000184305928$$
# $$h_{114}=1.15,I(x)=0.000184305928$$
# $$h_{115}=1.16,I(x)=0.000184305928$$
# $$h_{116}=1.17,I(x)=0.000184305928$$
# $$h_{117}=1.18,I(x)=0.000184305928$$
# $$h_{118}=1.19,I(x)=0.000184305928$$
# $$h_{119}=1.20,I(x)=0.000184305928$$
# $$h_{120}=1.21,I(x)=0.000184305928$$
# $$h_{121}=1.22,I(x)=0.000184305928$$
# $$h_{122}=1.23,I(x)=0.000184305928$$
# $$h_{123}=1.24,I(x)=0.000184305928$$
# $$h_{124}=1.25,I(x)=0.000184305928$$
# $$h_{125}=1.26,I(x)=0.000184305928$$
# $$h_{126}=1.27,I(x)=0.000184305928$$
# $$h_{127}=1.28,I(x)=0.000184305928$$
# $$h_{128}=1.29,I(x)=0.000184305928$$
# $$h_{129}=1.30,I(x)=0.000184305928$$
# $$h_{130}=1.31,I(x)=0.000184305928$$
# $$h_{131}=1.32,I(x)=0.000184305928$$
# $$h_{132}=1.33,I(x)=0.000184305928$$
# $$h_{133}=1.34,I(x)=0.000184305928$$
# $$h_{134}=1.35,I(x)=0.000184305928$$
# $$h_{135}=1.36,I(x)=0.000184305928$$
# $$h_{136}=1.37,I(x)=0.000184305928$$
# $$h_{137}=1.38,I(x)=0.000184305928$$
# $$h_{138}=1.39,I(x)=0.000184305928$$

# %%
I_simpson(0.01)
I_trapezoid(0.01)
# Out:
# 0.34134474607022336
# 0.34134272963911727
# 0.34134272963911727

# %%
import math
math.tan(1)
# Out:
# 1.5574077246549023

# %%
from __future__ import print_function, division
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
